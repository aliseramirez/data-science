# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Grammarly-App-User-Review" data-toc-modified-id="Grammarly-App-User-Review-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Grammarly App User Review</a></span><ul class="toc-item"><li><span><a href="#Data" data-toc-modified-id="Data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data</a></span></li></ul></li><li><span><a href="#Data-Collection" data-toc-modified-id="Data-Collection-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Collection</a></span></li><li><span><a href="#Text-Pre-processing" data-toc-modified-id="Text-Pre-processing-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Text Pre-processing</a></span><ul class="toc-item"><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Data Cleaning</a></span></li><li><span><a href="#Tokenization" data-toc-modified-id="Tokenization-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Tokenization</a></span></li><li><span><a href="#Stemming" data-toc-modified-id="Stemming-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Stemming</a></span></li><li><span><a href="#Lemmatizing" data-toc-modified-id="Lemmatizing-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Lemmatizing</a></span></li></ul></li><li><span><a href="#Text-Parsing" data-toc-modified-id="Text-Parsing-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Text Parsing</a></span></li><li><span><a href="#Initial-Data-Analysis" data-toc-modified-id="Initial-Data-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Initial Data Analysis</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Ratings" data-toc-modified-id="Ratings-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Ratings</a></span></li><li><span><a href="#Vote-Count" data-toc-modified-id="Vote-Count-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Vote Count</a></span></li><li><span><a href="#App-Version" data-toc-modified-id="App-Version-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>App Version</a></span></li></ul></li><li><span><a href="#Text-Representation" data-toc-modified-id="Text-Representation-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Text Representation</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Sentiment-Analysis" data-toc-modified-id="Sentiment-Analysis-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Sentiment Analysis</a></span></li><li><span><a href="#Topic-Modeling" data-toc-modified-id="Topic-Modeling-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Topic Modeling</a></span></li></ul></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Evaluation</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Grammarly App User Review
# Analyze the topics and sentiment of user reviews for Pinterest to determine suitable ideas for A/B testing and defining novel metrics.
#
# ## Data
# - review_id: unique identifier of review
# - title: summary of review
# - author: unique identifier of author
# - author_url: author url
# - version: version of the app
# - rating: numerical rating of the app
# - review: blob of user review of the app
# - vote_count: numerical count of unique users who like the review

# %% [markdown]
# # Data Collection

# %%
# Import libraries
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns;sns.set()

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
import spacy
import unicodedata

from scipy.stats import shapiro

import pprint
import time
import typing
import requests

# Visual Formatting
sns.set_style(rc={
 'axes.axisbelow': True,
 'axes.edgecolor': '.8',
 'axes.facecolor': 'white',
 'axes.grid': True,
 'axes.labelcolor': '.15',
 'axes.spines.bottom': True,
 'axes.spines.left': True,
 'axes.spines.right': True,
 'axes.spines.top': True,
 'figure.facecolor': 'white',
 'xtick.bottom': False,
 'xtick.color': '.15',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': '.15',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False})

# %%
# Web scraping of user reviews 
def is_error_response(http_response, seconds_to_sleep: float = 1) -> bool:
    """
    Returns False if status_code is 503 (system unavailable) or 200 (success),
    otherwise it will return True (failed). This function should be used
    after calling the commands requests.post() and requests.get().

    :param http_response:
        The response object returned from requests.post or requests.get.
    :param seconds_to_sleep:
        The sleep time used if the status_code is 503. This is used to not
        overwhelm the service since it is unavailable.
    """
    if http_response.status_code == 503:
        time.sleep(seconds_to_sleep)
        return False

    return http_response.status_code != 200

def get_json(url) -> typing.Union[dict, None]:
    """
    Returns json response if any. Returns None if no json found.

    :param url:
        The url go get the json from.
    """
    response = requests.get(url)
    if is_error_response(response):
        return None
    json_response = response.json()
    return json_response

def get_reviews(app_id, page=1) -> typing.List[dict]:
    """
    Returns a list of dictionaries with each dictionary being one review. 
    
    :param app_id:
        The app_id you are searching. 
    :param page:
        The page id to start the loop. Once it reaches the final page + 1, the 
        app will return a non valid json, thus it will exit with the current 
        reviews. 
    """
    reviews: typing.List[dict] = [{}]

    while True:
        url = (f'https://itunes.apple.com/rss/customerreviews/id={1158877342}/'
               f'page={page}/sortby=mostrecent/json')
        json = get_json(url)

        if not json:
            return reviews

        data_feed = json.get('feed')

        if not data_feed.get('entry'):
            get_reviews(app_id, page + 1)

        reviews += [
            {
                'review_id': entry.get('id').get('label'),
                'title': entry.get('title').get('label'),
                'author': entry.get('author').get('name').get('label'),
                'author_url': entry.get('author').get('uri').get('label'),
                'version': entry.get('im:version').get('label'),
                'rating': entry.get('im:rating').get('label'),
                'review': entry.get('content').get('label'),
                'vote_count': entry.get('im:voteCount').get('label')
            }
            for entry in data_feed.get('entry')
            if not entry.get('im:name')
        ]

        page += 1
reviews_dict = get_reviews('1158877342')

# %%
reviews=pd.DataFrame(reviews_dict[1:]) 
reviews.head()
# Out:
#               author                                        author_url rating  \
# 0         Chollathon   https://itunes.apple.com/us/reviews/id154691946      1
# 1   undercover pizzq   https://itunes.apple.com/us/reviews/id542732992      3
# 2  Crystal(mug shot)   https://itunes.apple.com/us/reviews/id351819855      3
# 3           Vee.0222  https://itunes.apple.com/us/reviews/id1017024576      5
# 4      Damaris 🥰☺️😆😀   https://itunes.apple.com/us/reviews/id947625305      3
#
#                                               review   review_id  \
# 0  I mostly rely on Grammarly because English is ...  5758601188
# 1  I was hoping that it would be more than a slig...  5757083923
# 2  It's good but continuously messes up some thin...  5754680966
# 3  Grammarly is amazing. It makes it incredibly e...  5752622807
# 4  Well, I need extra help with spelling but we h...  5752078991
#
#                                               title version vote_count
# 0  It's not as smart as I used this app a year ago.   1.8.1          0
# 1                                It could be better   1.8.1          0
# 2                                               Meh   1.8.1          0
# 3                                         I LOVE IT   1.8.1          0
# 4                                             Money   1.8.1          0

# %% [markdown]
# # Text Pre-processing

# %% [markdown]
# ## Data Cleaning

# %%
# Replace values with accent marks
cols = reviews.select_dtypes(include=[np.object]).columns
def remove_accented_chars(reviews, cols):
    reviews[cols] = reviews[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))
    return reviews
remove_accented_chars(reviews, cols)
# Out:
#                          author  \
# 0                    Chollathon
# 1              undercover pizzq
# 2             Crystal(mug shot)
# 3                      Vee.0222
# 4                      Damaris
# 5                   bskzksbsocm
# 6                     ellie2346
# 7
# 8                 Boulder Beast
# 9             Yshergyshsbdbdjdj
# 10               Team Monkeyboy
# 11            productreview.com
# 12            redredcolereedred
# 13                  unxcorngurl
# 14                    djjjfjrhr
# 15                  jpopielaski
# 16               Raccoonking-11
# 17                          mot
# 18              chickens4ever12
# 19                    grovespot
# 20                  miss beckyc
# 21                   LeonShield
# 22                      camille
# 23                   ,.,.,.,.,g
# 24      Instagram: beautybymadi
# 25
# 26                  Daisy Nenee
# 27
# 28                       ebug55
# 29                yhhnbgtr&vcde
# ..                          ...
# 470                     mi.1873
# 471                Razorback614
# 472                   Lex Ghazi
# 473        urmommmmmmmmmmmmamma
# 474                  Isabella43
# 475                  ShawnHoo50
# 476                 Kaylaxoxoxo
# 477           andi mack lover45
# 478                   Simone.Va
# 479                    AcheronP
# 480            hi i a guy lolol
# 481            Newsnapchatblows
# 482                  Bloc bucks
# 483                 FibroManMMJ
# 484                     aurjola
# 485                  ArmourLuck
# 486                   colby2134
# 487                  tlgillette
# 488                   Spamela57
# 489           DontMindVanBurren
# 490              AlexBraveheart
# 491                    bob 1152
# 492                 Kaleb moody
# 493          Cari Devine-Blount
# 494                   Floormann
# 495                      jayrdg
# 496  Judy1234567891012345678910
# 497                   zm8675309
# 498              igotgoodgrades
# 499            BabbyLemonSprout
#
#                                            author_url rating  \
# 0     https://itunes.apple.com/us/reviews/id154691946      1
# 1     https://itunes.apple.com/us/reviews/id542732992      3
# 2     https://itunes.apple.com/us/reviews/id351819855      3
# 3    https://itunes.apple.com/us/reviews/id1017024576      5
# 4     https://itunes.apple.com/us/reviews/id947625305      3
# 5    https://itunes.apple.com/us/reviews/id1149389630      5
# 6     https://itunes.apple.com/us/reviews/id147426054      5
# 7      https://itunes.apple.com/us/reviews/id32541662      4
# 8     https://itunes.apple.com/us/reviews/id220640647      1
# 9     https://itunes.apple.com/us/reviews/id460635613      1
# 10    https://itunes.apple.com/us/reviews/id101489643      4
# 11    https://itunes.apple.com/us/reviews/id696023978      1
# 12   https://itunes.apple.com/us/reviews/id1059177741      4
# 13   https://itunes.apple.com/us/reviews/id1151358521      1
# 14   https://itunes.apple.com/us/reviews/id1100876878      5
# 15    https://itunes.apple.com/us/reviews/id949482849      5
# 16     https://itunes.apple.com/us/reviews/id86721692      3
# 17    https://itunes.apple.com/us/reviews/id608629063      4
# 18    https://itunes.apple.com/us/reviews/id374406539      1
# 19    https://itunes.apple.com/us/reviews/id715171780      1
# 20    https://itunes.apple.com/us/reviews/id872427784      5
# 21    https://itunes.apple.com/us/reviews/id130144781      1
# 22    https://itunes.apple.com/us/reviews/id822424316      5
# 23   https://itunes.apple.com/us/reviews/id1150536479      1
# 24    https://itunes.apple.com/us/reviews/id953867895      4
# 25    https://itunes.apple.com/us/reviews/id872182587      5
# 26     https://itunes.apple.com/us/reviews/id48814462      5
# 27    https://itunes.apple.com/us/reviews/id189097965      1
# 28   https://itunes.apple.com/us/reviews/id1141965285      4
# 29    https://itunes.apple.com/us/reviews/id382867785      1
# ..                                                ...    ...
# 470  https://itunes.apple.com/us/reviews/id1062354828      1
# 471   https://itunes.apple.com/us/reviews/id238323286      4
# 472    https://itunes.apple.com/us/reviews/id85052358      1
# 473   https://itunes.apple.com/us/reviews/id895836569      1
# 474   https://itunes.apple.com/us/reviews/id879223731      1
# 475  https://itunes.apple.com/us/reviews/id1021314025      4
# 476   https://itunes.apple.com/us/reviews/id118313962      1
# 477   https://itunes.apple.com/us/reviews/id486715461      5
# 478   https://itunes.apple.com/us/reviews/id722462718      1
# 479    https://itunes.apple.com/us/reviews/id19213863      1
# 480   https://itunes.apple.com/us/reviews/id727226370      5
# 481   https://itunes.apple.com/us/reviews/id302123104      1
# 482   https://itunes.apple.com/us/reviews/id551244040      1
# 483   https://itunes.apple.com/us/reviews/id502754931      1
# 484   https://itunes.apple.com/us/reviews/id957651660      5
# 485  https://itunes.apple.com/us/reviews/id1070665160      5
# 486   https://itunes.apple.com/us/reviews/id977955586      5
# 487    https://itunes.apple.com/us/reviews/id32333513      1
# 488   https://itunes.apple.com/us/reviews/id113555744      3
# 489   https://itunes.apple.com/us/reviews/id201186584      1
# 490   https://itunes.apple.com/us/reviews/id240592200      1
# 491   https://itunes.apple.com/us/reviews/id851232878      1
# 492  https://itunes.apple.com/us/reviews/id1089182841      5
# 493   https://itunes.apple.com/us/reviews/id113407553      1
# 494   https://itunes.apple.com/us/reviews/id458025442      5
# 495   https://itunes.apple.com/us/reviews/id753361951      5
# 496   https://itunes.apple.com/us/reviews/id627324768      5
# 497  https://itunes.apple.com/us/reviews/id1105309272      1
# 498   https://itunes.apple.com/us/reviews/id414665022      1
# 499  https://itunes.apple.com/us/reviews/id1083591622      1
#
#                                                 review   review_id  \
# 0    I mostly rely on Grammarly because English is ...  5758601188
# 1    I was hoping that it would be more than a slig...  5757083923
# 2    It's good but continuously messes up some thin...  5754680966
# 3    Grammarly is amazing. It makes it incredibly e...  5752622807
# 4    Well, I need extra help with spelling but we h...  5752078991
# 5    I am staring to download it I am downloading i...  5749512641
# 6    I love Grammarly so much for my school docs an...  5746486204
# 7    I really like this app and I was very excited ...  5745481290
# 8    Absolutely horrible. The spellcheck is trash, ...  5744315100
# 9    Don't do it. I wasted 139.99 and it only works...  5743059930
# 10   I have regular Grammarly and not the premium v...  5742349934
# 11   Its struggling to be fluid with my iPad pro It...  5739371857
# 12   Very good Grammarly, without premium still goo...  5738567361
# 13   So, I saw an ad for the computer application. ...  5737864671
# 14                                           I likenit  5736700519
# 15   Grammarly catches all of my errors when I'm wr...  5735721183
# 16   The app itself is very helpful but needs to ha...  5734510395
# 17   Great app, would be even better if it had swip...  5733876405
# 18   When there is a spelling problem it tells me t...  5733253103
# 19   I want to cancel NOW!  I did not see a charge ...  5733229917
# 20   without it. My grammar and vocabulary is kind ...  5731717649
# 21   I like the keypad on my phone better. I like i...  5729150280
# 22   Grammarly is a very effective app I am using i...  5728934000
# 23   I honestly dont like premium because its kind ...  5727880635
# 24   I wish I had more without having to pay beside...  5727084756
# 25   this is a great app even though i'm good at gr...  5726860451
# 26                                          I love it!  5726538475
# 27   The app will not work if you did not allow key...  5726126691
# 28   At first, this was a good idea (and still is) ...  5723003848
# 29   They want to send your personal information, c...  5722772380
# ..                                                 ...         ...
# 470  Premium is expensive for a college student who...  5245175156
# 471  I really wanted to use the premium features bu...  5244377022
# 472  Only works if you allow them to save all ur da...  5240009662
# 473                   you cant do ios 13 slide to type  5239972308
# 474  They charged me for an annual subscription ins...  5238424789
# 475  It corrects my mistakes when my mind goes way ...  5238243805
# 476  Downloaded this app to check some of my gramma...  5238066204
# 477            It is like your own private book editor  5237472839
# 478  Every time I were a name of someone, and it's ...  5236937590
# 479  The concept of Grammarly is excellent. Unfortu...  5235600750
# 480  I'm a 6th-grade middle school student and this...  5234224481
# 481  No thanks! In order for the keyboard to work g...  5234089506
# 482  it keeps sending emails and it wont stop sendi...  5233802545
# 483  Downloaded this app to have my grammar checked...  5231764616
# 484  It works really good. And helps with my. Spell...  5230162482
# 485  It's amazing! It helps me with everything, and...  5229973428
# 486                       Can I do this on my computer  5229220271
# 487  Great app if you only use the onscreen keyboar...  5228710611
# 488  Ive used Grammarly for some time on my laptop ...  5226925170
# 489  While the mac and web version are great and do...  5226466410
# 490  I downloaded and deleted the program. Grammarl...  5225413789
# 491  I signed up as soon as I noticed it cost money...  5218391169
# 492               This app is so so helpful for typing  5217884770
# 493  I like Grammarly my main problem is the email ...  5217533776
# 494  I thought I was competent with writing English...  5216706420
# 495        Im learning more and for that Im great full  5213818556
# 496                                 A really good app.  5213353423
# 497  First off no physical keyboard support. Useles...  5212162695
# 498  In the ad I saw for this app it didnt say that...  5209425356
# 499  Okay so Im on wattpad and the app keeps tellin...  5206487080
#
#                                                  title version vote_count
# 0     It's not as smart as I used this app a year ago.   1.8.1          0
# 1                                   It could be better   1.8.1          0
# 2                                                  Meh   1.8.1          0
# 3                                            I LOVE IT   1.8.1          0
# 4                                                Money   1.8.1          0
# 5                                            Great app   1.8.1          0
# 6                                 Grammarly for school   1.8.1          0
# 7                                 Premium costs money    1.8.1          0
# 8                                             Horrible   1.8.1          0
# 9               If you are planning to buy premium....   1.8.1          0
# 10   Good app, but you cant get much help without p...   1.8.1          0
# 11                                          Needs work   1.8.1          0
# 12                                           Grammarly   1.8.1          0
# 13      Underwhelming and you have to pay for features   1.8.1          0
# 14                                           I like it   1.8.0          0
# 15                                             Awesome   1.8.0          0
# 16                                           Great but   1.8.0          0
# 17                          Add swipe to the keyboard.   1.8.0          0
# 18                                       Doesn't work!   1.8.0          0
# 19                                           Canceling   1.8.0          0
# 20   I am really enjoying the Grammarly app. I woul...   1.8.0          0
# 21                                          Cumbersome   1.8.0          0
# 22                      Grammarly is my Guardian angel   1.8.0          0
# 23                              It's kind of annoying.   1.8.0          0
# 24                               I have mixed feelings   1.8.0          0
# 25                                              GREAT    1.8.0          0
# 26                                            Awesome!   1.8.0          0
# 27                                             Bad App   1.8.0          0
# 28                                           Usability   1.8.0          0
# 29      Read the privacy policy first, before you buy!   1.8.0          0
# ..                                                 ...     ...        ...
# 470                                      Too expensive   1.7.0          1
# 471                                      Nice! But....   1.7.0          0
# 472                                               Booo   1.7.0          1
# 473                                   No slide to type   1.7.0          1
# 474                                 Wrongfully Charged   1.7.0          1
# 475                                           Cool app   1.7.0          0
# 476    Dont waste your time unless you want to pay $12   1.7.0          0
# 477                                          Great app   1.7.0          0
# 478                                              Names   1.7.0          1
# 479                                Dreadfully Annoying   1.7.0          2
# 480                                      Helps so much   1.7.0          0
# 481                Grammarly can view anything I type?   1.7.0          2
# 482                                           Horrible   1.7.0          1
# 483                                       Not worth it   1.6.6          2
# 484                                              Ari s   1.6.6          0
# 485                                              10/10   1.6.6          0
# 486                                           Question   1.6.6          1
# 487                    Does not support Smart Keyboard   1.6.6          1
# 488                 Not worth giving up personal info!   1.6.6          0
# 489                              disgusting experience   1.6.6          3
# 490                                  Useless (for now)   1.6.6          0
# 491                                            Support   1.6.6          1
# 492                    I like this app to help me type   1.6.6          0
# 493         I have tried for years to correct my email   1.6.6          0
# 494                                          Thank you   1.6.6          0
# 495                                         Thank you.   1.6.6          0
# 496                                      Best App Ever   1.6.6          0
# 497  Desktop app may be alright, but the iPad app isnt   1.6.6          0
# 498                                               Lies   1.6.6          1
# 499                           Its annoying me with ads   1.6.6          1
#
# [500 rows x 8 columns]

# %%
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

remove_special_characters("Well this was fun! What do you think? 123#@!", 
                          remove_digits=True)

# %% [markdown]
# ## Tokenization

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

remove_stopwords("The, and, if are stopwords, computer is not")

# %% [markdown]
# ## Stemming

# %%
def simple_stemmer(text):
    ps = nltk.porter.PorterStemmer()
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

simple_stemmer("My system keeps crashing his crashed yesterday, ours crashes daily")

# %% [markdown]
# ## Lemmatizing

# %%
def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

lemmatize_text("My system keeps crashing! his crashed yesterday, ours crashes daily")

# %%
from sklearn.feature_extraction.text import CountVectorizer
count=CountVectorizer()

def tokenize(reviews):
    """
    Params:
        - Reviews
         
    Returns:
        - Tokens (n-grams)
        
    """
    review_doc=np.array(reviews)
    bag=count.fit_transform(review_doc)
    return count.vocabulary_

tokenize(neg_reviews.review)

# %% [markdown]
# # Text Parsing

# %% [markdown]
# # Initial Data Analysis

# %%
def initial_analysis(df):
    """
    Report for initial data analysis for given dataframe
    
    Params:
        - df
    
    Returns:
         - Report of dataset shape and datatypes of all columns
         
    """
    print('Report of Initial Data Analysis:')
    print(f'Shape of dataframe: {df.shape}')
    print(f'Features and Data Types: \n {df.dtypes}')
initial_analysis(reviews)

# %%
def percent_missing(df):
    """
    Calculate percent of missing values for each column in dataset
    
    Params:
        - df
        
    Returns:
        - Dictionary of columns and percent of missing records
    
    """
    col=list(df.columns)
    perc=[round(df[c].isna().mean()*100,2) for c in col]
    miss_dict=dict(zip(col,perc))
    return miss_dict
percent_missing(reviews)

# %%
version_lst=list(reviews.version.unique())
version_dict={}
def version_sub(version_lst):
    """
    Given a list of unique app versions retrieve the first 3 characters of the string
    remove the delimiter '.' and convert to numeric. Find the maximum value based on major
    and first minor update value. Return the versions to be included in analysis.
    
    Params:
        - version_lst, list of unique versions
        
    Returns:
        - List of unique and most recent app versions with the same major and minor update
    
    """
    temp_sub=[]
    for v in version_lst:
        temp_sub.append(v[:3].replace('.',''))
        temp_sub=[int(s) for s in temp_sub]
    version_dict.update(dict(zip(version_lst,temp_sub)))
    return version_dict     
version_sub(version_lst)

# %%
curr_version=[]
def app_version(version_dict):
    """
    Given a dictionary of sorted unique app versions and the first two values as int determine the
    most recent version and all versions containing the same first two values.
    
    Params:
        - version_dict
        
    Returns:
        - List of app versions to retain in dataset
    
    """
    max_version=max(list(version_dict.values()))
    for k in list(version_dict.keys()):
        if version_dict[k] == max_version:
            curr_version.append(k)
    return curr_version
app_version(version_dict)

# %%
def filter_reviews(df,curr_version):
    """
    Filter the reviews based on the version number
    Params:
        - df
        - curr_version
    
    Returns:
        - filtered df
        
    """
    df=df[df.version.isin(curr_version)]
    return df
filter_reviews(reviews,curr_version)

# %%
num_feat=[]
def numerical_features(df):
    """
    Determine the columns that are numerical
    
    Params:
         - df
     
     Returns:
         - List of columns that are numerical
     
    """
    col=['rating','vote_count']
    reviews[col]=reviews[col].astype('int')
    
    for c in list(df.columns):
        if (df[c].dtypes) == 'int' or (df[c].dtypes) == 'float':
            num_feat.append(c)
    return num_feat
numerical_features(reviews)

# %%
norm_dict={}
def sample_normality(df,col_list):
    """
    Given a dataframe determines whether each numerical column is Gaussian 

    Ho = Assumes distribution is not Gaussian
    Ha = Assumes distribution is Gaussian

    Params:
        - df

    Returns:
        - List of columns non-gaussian and W-statistic

    """
    non_gauss=[]
    w_stat=[]
    
    # Determine if each sample of numerical feature is gaussian
    alpha = 0.05
    for f in num_feat:
        stat,p=shapiro(df[f])
        if p <= alpha: # Reject Ho -- Distribution is not normal
            non_gauss.append(f)
            w_stat.append(stat)
            
    # Dictionary of numerical features not gaussian and W-statistic 
    temp_dict=dict(zip(non_gauss,w_stat))
    norm_dict.update(temp_dict)
    return norm_dict
sample_normality(reviews,num_feat)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Ratings

# %%
ax=sns.countplot(x='rating',data=reviews); # Ordinal
ax.set_title('Frequency of User Review Ratings')
ax.set_ylabel('Count of Rating')
ax.set_xlabel('Rating')

# %% [markdown]
# ## Vote Count

# %%
print(reviews.vote_count.value_counts()) # No votes on reviews

# %% [markdown]
# ## App Version

# %%
print(reviews.version.value_counts()) # Ordinal

# %% [markdown]
# # Text Representation

# %%
def sentiment_label(df):
    """
    Define labels for sentiment by the user review rating by converting the string to 
    integer. Create new column to define the sentiment.
    
    Params:
        - df
        
    Returns:
        - Sentiment labels
        
    """
    df['rating']=df['rating'].astype('int')
    df['sentiment']=np.where(df['rating']>=4,1,0)
sentiment_label(reviews)

# %%
def subset_reviews(df):
    """
    Params:
        - dataframe
    
    Returns:
        - negative reviews
        
    """
    reviews=reviews[['review','sentiment']]
    reviews=reviews[reviews.sentiment==0]
subset_reviews(reviews)

# %%
def clean_text(text):
    """
    Remove punctuation and all other characters from the reviews and 
    returned all text in lower case format.
    
    Params:
        - Reviews
        
    Returns:
        - Revised reviews
        
    """
    emoticons=re.findall('(?::|;|=)(?:-)?(?:\)|\(D|P)',text)
    text=(re.sub('[\W]+',' ',text.lower()) + ' '.join(emoticons).replace('-',''))
    return text

neg_reviews['review']=neg_reviews['review'].apply(clean_text)

# %% [markdown]
# # Modeling

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf=TfidfTransformer(use_idf=True,
                       norm='l2',
                       smooth_idf=True)

# %%
np.set_printoptions(precision=2)

# %%
print(tfidf.fit_transform(count.fit_transform(review_doc)).toarray())

# %% [markdown]
# ## Sentiment Analysis
# - Segment app reviews by polarity of the users sentiment to prirotize negative reviews
# - Rating can be used as validation for determining if these reviews are positive, negative or neutral

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Conclusion
